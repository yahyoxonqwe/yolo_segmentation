# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO('yolov8n-seg.pt')

# %%
# !yolo task=segment mode=train model=yolov8n-seg.pt data = "Windows_datasets/data.yaml" epochs = 10
# Out:
# New https://pypi.org/project/ultralytics/8.0.200 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.158 🚀 Python-3.9.17 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# ...

# %%
model = YOLO('/home/airi/yolo/runs/segment/train9/weights/best.pt')
image = cv2.imread("/home/airi/Mylove/github/yolo_segmentation/Windows_datasets/train/images/cmp_x0136_jpg.rf.a1bef20fcc49a2ef991b31fadf8e0981.jpg")
image = cv2.cvtColor(image , cv2.COLOR_BGR2RGB)
result = model.predict(source = image)
# Out:
# 0: 640x640 44 Windows, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
plt.imshow(result[0].plot())
